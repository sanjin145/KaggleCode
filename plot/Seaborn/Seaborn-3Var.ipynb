# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)
ord_map = map(ord,"distributions")
print(ord_map)
print(type(ord_map))#<class 'map'>
sum_ord_map = sum(ord_map)
print(sum_ord_map)
print(type(sum_ord_map))#<class 'int'>
np.random.seed(sum_ord_map)
# Out:
# ...
# <class 'map'>
# 1427
# <class 'int'>

# %%
#生成100个符合正态分布的数
x = np.random.normal(size=100)
#绘画直方图
#displot()集合了matplotlib的hist()与核函数估计kdeplot的功能
sns.distplot(x,kde=False)

# %%
sns.distplot(x, bins=20, kde=False)

# %% [markdown]
# ### 数据分布情况  ###

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma)

# %% [markdown]
# 根据均值和协方差生成数据

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])
df
# Out:
#             x         y
# 0    2.190873  2.902961
# 1    0.387901  3.441322
# 2   -1.304909  0.586173
# 3   -0.016867  0.907323
# 4    0.284953  1.189304
# 5   -0.050474  0.670980
# 6    0.722333  1.062931
# 7   -0.026326  1.294782
# 8   -0.788587  0.669541
# 9   -0.372764  1.731517
# 10   0.793945  0.844329
# 11  -1.587542 -0.325003
# 12   0.982330 -0.079164
# 13  -0.709190  0.617583
# 14  -0.320185  1.700419
# 15  -1.107602  1.969576
# 16  -0.152153  0.863231
# 17   0.672152 -0.337424
# 18  -0.054459  1.291490
# 19  -0.854301  0.461832
# 20  -1.467110  0.988230
# 21   0.769059  0.464059
# 22   0.864182  2.160841
# 23  -0.320895 -0.682581
# 24   0.201675  0.767145
# 25   0.910064  0.352476
# 26  -0.203879  2.281753
# 27  -1.968103  0.814249
# 28  -0.312965  1.835252
# 29  -1.017516  2.107019
# ..        ...       ...
# 170 -0.820467  2.150415
# 171  1.987218  2.863377
# 172  0.541367  1.672410
# 173 -0.230476  1.188198
# 174  0.654961  3.311254
# 175 -0.393180 -0.064882
# ...

# %% [markdown]
# ###  观测两个变量之间的分布关系最好用散点图 ###

# %%
#同时把两个变量的散点图和直方图画出来
sns.jointplot(x="x", y="y", data=df);
#当点很多时，会聚集在一起看不清

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    #指定kind为hex,与上面的joint进行区分，看出来哪块数据量比较大
    sns.jointplot(x=x, y=y, kind="hex", color="k")

# %%
iris = sns.load_dataset("iris")
#假设有n个特征（列）
#pairplot会生成 n * n个散点图（自身特征则生成直方图），表示特征两两之间的关系
#有点类似于协方差矩阵
sns.pairplot(iris)
